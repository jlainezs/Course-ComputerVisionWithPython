# %%
from keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# (50000, 32, 32, 3)

# %%
x_train[0].shape
# Out:
# (32, 32, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(x_train[0])

# %%
x_train.max()
# Out:
# np.uint8(255)

# %%
x_train = x_train/255
y_test = y_test/255

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
from keras.utils import to_categorical

# %%
y_cat_train = to_categorical(y_train, 10)
y_cat_test = to_categorical(y_test, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(4,4), activation='relu', input_shape=(32,32,3)))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters=64, kernel_size=(4,4), activation='relu', input_shape=(32,32,3)))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 29, 29, 32)     │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 64)     │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       409,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 446,826 (1.70 MB)
#  Trainable params: 446,826 (1.70 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_cat_train, verbose=1, epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6092 - loss: 1.1158
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6703 - loss: 0.9514
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7135 - loss: 0.8311
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7492 - loss: 0.7331
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7790 - loss: 0.6465
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8054 - loss: 0.5779
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8252 - loss: 0.5142
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8442 - loss: 0.4649
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8590 - loss: 0.4270
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8701 - loss: 0.3921

# %%
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
model.evaluate(x_test, y_cat_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2511 - loss: 1294.0264
# [1294.0263671875, 0.25110000371932983]

# %%
from sklearn.metrics import classification_report
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(classification_report(y_test, predictions))
#
# File D:\Projectes\Cursos\ComputerVisionWithPython\ComputerVisionWithPythonSrc\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File D:\Projectes\Cursos\ComputerVisionWithPython\ComputerVisionWithPythonSrc\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2948, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2840 """Build a text report showing the main classification metrics.
#    2841
#    2842 Read more in the :ref:`User Guide <classification_report>`.
#    (...)   2944 <BLANKLINE>
#    2945 """
#    2947 y_true, y_pred = attach_unique(y_true, y_pred)
# -> 2948 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2950 if labels is None:
#    2951     labels = unique_labels(y_true, y_pred)
#
# File D:\Projectes\Cursos\ComputerVisionWithPython\ComputerVisionWithPythonSrc\.venv\Lib\site-packages\sklearn\metrics\_classification.py:106, in _check_targets(y_true, y_pred)
#     103     y_type = {"multiclass"}
#     105 if len(y_type) > 1:
# --> 106     raise ValueError(
#     107         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     108             type_true, type_pred
#     109         )
#     110     )
#     112 # We can't have more than one value on y_type => The set is no more needed
#     113 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous and continuous-multioutput targets
