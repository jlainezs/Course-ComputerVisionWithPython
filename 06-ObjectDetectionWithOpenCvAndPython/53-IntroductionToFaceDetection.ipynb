# %%
# https://en.wikipedia.org/wiki/Haar-like_feature
# Face detection using Haar Cascades, key component of Viola-Jones object detection framework
# Face detection is not face recognition

# detect features: edges, lines, four rectangle.
# Viola-Jones algorith uses **integral** image which results in a O(1) running time.
# An integral image is also known as a summed area table.

# Face detection
# Front facing image of a person's face
# To grayscale
# Begin Haar Cascades detection (edge, line ... )
